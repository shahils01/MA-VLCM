# %%
import numpy as np
import torch
import pandas as pd
from datasets import load_dataset

# %%
# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("uygarkurt/simple-image-captions")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'caption'],
#         num_rows: 16
#     })
# })

# %%
import base64
import io
from PIL import Image
import torch
import torch.nn as nn 
import torchvision.transforms as transforms
from transformers import LlamaConfig, Llama4ForCausalLM, LlamaTokenizer
from transformers import ViTConfig, ViTModel
from torch.utils.data import Dataset, DataLoader

from tqdm import tqdm
import random
import numpy as np

# %%
SEED =  42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
BATCH_SIZE = 16
N_HIDDEN_LAYERS = 16
MAX_LENGTH = 16
EVAL_INTERVAL = 10
LEARNING_RATE = 9e-4
EPOCHS = 10
N_EMBD = 128
N_HEAD = 8
N_LAYER = 8
DROPOUT = 0.4
IMG_SIZE = 96
PATCH_SIZE = 16
IMAGE_EMBED_DIM = 512
N_CHANNELS = 3
MAX_POSITION_EMBEDINGS =  128

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' 

tokenizer = LlamaTokenizer.from_pretrained("NousResearch/Llama-2-7b-chat-hf")
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_style = 'right'
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
image_dir =

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'caption'],
#         num_rows: 16
#     })
# })

# %%
ds['train']['caption']
# Out:
# Column(['red car', 'astronaut in a white space suit', 'black television on a table', 'brown horse running', 'wine bottle', ...])
